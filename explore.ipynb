# %%
import pandas as pd     
import datetime as dt
import altair as alt

# %%
df6 = pd.read_csv("data/PuertoRico_COUNTY2016.csv")
df8 = pd.read_csv("data/PuertoRico_COUNTY2018.csv")

# %%
dffull = pd.concat([df6,df8], ignore_index=True)
dffull
# Out:
#      FID  ST        STATE ST_ABBR        COUNTY   FIPS  \
# 0    0.0  72  PUERTO RICO      PR      Adjuntas  72001
# 1    1.0  72  PUERTO RICO      PR        Aguada  72003
# 2    2.0  72  PUERTO RICO      PR     Aguadilla  72005
# 3    3.0  72  PUERTO RICO      PR  Aguas Buenas  72007
# 4    4.0  72  PUERTO RICO      PR      Aibonito  72009
# ..   ...  ..          ...     ...           ...    ...
# 151  NaN  72  PUERTO RICO      PR       Guánica  72055
# 152  NaN  72  PUERTO RICO      PR        Jayuya  72073
# 153  NaN  72  PUERTO RICO      PR         Lajas  72079
# 154  NaN  72  PUERTO RICO      PR       Maricao  72093
# 155  NaN  72  PUERTO RICO      PR  Barranquitas  72019
#
#                                 LOCATION  AREA_SQMI  E_TOTPOP  M_TOTPOP  ...  \
# 0        Adjuntas Municipio, Puerto Rico  66.689751   18760.0       0.0  ...
# 1          Aguada Municipio, Puerto Rico  30.850824   40083.0       0.0  ...
# ...

# %%
dffull.to_csv('data.csv')
